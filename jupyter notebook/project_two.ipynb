# %%
import pandas as pd
import numpy as np
import requests

# %%
dtable = pd.read_html('plover_1.html')
elevation = dtable[5].iloc[:,[3]]
elevation_filter = elevation.iloc[[6,9]]
elevation_filter=elevation_filter.T
elevation_filter=elevation_filter.rename(columns = {6:'sea_floor', 9:'rotary_table'}, inplace=False)
elevation_final=elevation_filter.reset_index(drop=True)
elevation_final.index = np.arange(1, len(elevation_final) + 1)
elevation_final= elevation_final.rename_axis('elevation_id')
elevation_finale = elevation_final.dropna()
elevation_finale
# Out:
#              sea_floor       rotary_table
# elevation_id
# 1             -58m MSL  kelly bushing 34m

# %%
'''from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:password@localhost:5432/wellwell_db').connect()
elevation_final.to_sql('elevation', engine,if_exists = 'replace')'''
# Out:
# "from sqlalchemy import create_engine\nengine = create_engine('postgresql://postgres:password@localhost:5432/wellwell_db').connect()\nelevation_final.to_sql('elevation', engine,if_exists = 'replace')"

# %%
dtable = pd.read_html('plover_1.html')
biostrat = dtable[-2]
biostrat_filter1 = biostrat.iloc[:,[0,1]]
biostrat_filter2 = biostrat_filter1.iloc[4:]
biostrat_filter2 = biostrat_filter2.rename(columns = {0:'depth', 1:'zone',4:'class', 5:'readings',6:'age'}, inplace=False)
biostrat_filter2.reset_index(drop=True)
biostrat_filter2.index = np.arange(1, len(biostrat_filter2) + 1)
biostrat_final= biostrat_filter2.rename_axis('biostrat_id')
biostrat_finale = biostrat_final.dropna()
biostrat_finale
# Out:
#                 depth                                zone
# biostrat_id
# 1                 396       Diconodinium multispinum 1aii
# 2                 396    Appendicisporites distocarinatus
# 3                 809       Pseudoceratium ludbrookiae 1b
# 4                 992  Muderongia australis 2diii Subzone
# 5                1027      Muderongia australis 2di-2diii
# 6                1060      Egmontodinium torynum 4ai-4aii
# 7                1085    Dissimulidinium lobispinosum 4bi
# 8                1091           Kalyptea wisemaniae 4biii
# 9                1097         Dingodinium jurassicum 5a-b
# 10               1100    Dissimulidinium lobispinosum 4bi
# 11               1195    Dissimulidinium lobispinosum 4bi
# 12               1212               Wanaea spectabilis 6c
# 13               1219                 Wanaea digitata 7bi
# 14             1225.3   Lower Wanaea digitata 7bi Subzone
# 15               1568    lower Samaropollenites speciosus
# 16               1716         Kraeuselisporites saeptatus
# 17               2134           Lunatisporites pellucidus
# 18           2145.792           Lunatisporites pellucidus
# 19           2170.176           Lunatisporites pellucidus
# 20               2200       Protohaploxypinus microcorpus
# 21           2246.376                      upper Stage 5a
# 22            2346.96                      upper Stage 5a
# 23           2420.112                      lower Stage 5c

# %%
biostrat_finale['borehole_id'] = 1
# Out:
# C:\Users\rayca\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
biostrat_finale
# Out:
#                 depth                                zone  borehole_id
# biostrat_id
# 1                 396       Diconodinium multispinum 1aii            1
# 2                 396    Appendicisporites distocarinatus            1
# 3                 809       Pseudoceratium ludbrookiae 1b            1
# 4                 992  Muderongia australis 2diii Subzone            1
# 5                1027      Muderongia australis 2di-2diii            1
# 6                1060      Egmontodinium torynum 4ai-4aii            1
# 7                1085    Dissimulidinium lobispinosum 4bi            1
# 8                1091           Kalyptea wisemaniae 4biii            1
# 9                1097         Dingodinium jurassicum 5a-b            1
# 10               1100    Dissimulidinium lobispinosum 4bi            1
# 11               1195    Dissimulidinium lobispinosum 4bi            1
# 12               1212               Wanaea spectabilis 6c            1
# 13               1219                 Wanaea digitata 7bi            1
# 14             1225.3   Lower Wanaea digitata 7bi Subzone            1
# 15               1568    lower Samaropollenites speciosus            1
# 16               1716         Kraeuselisporites saeptatus            1
# 17               2134           Lunatisporites pellucidus            1
# 18           2145.792           Lunatisporites pellucidus            1
# 19           2170.176           Lunatisporites pellucidus            1
# 20               2200       Protohaploxypinus microcorpus            1
# 21           2246.376                      upper Stage 5a            1
# 22            2346.96                      upper Stage 5a            1
# 23           2420.112                      lower Stage 5c            1

# %%
#elevetion_csv="elevation.csv"
#biostrat_csv="biostrat.csv"

# %%
#elevation_finale.to_csv(elevetion_csv,index=True)
#biostrat_finale.to_csv(biostrat_csv,index=False)

# %%
from sqlalchemy import create_engine
from config import username, password 
hostname = "localhost"  # usually is localhost 
port = "5432" # usually is 5432 
database = "wellwell_db" 
engine = create_engine(f'postgresql://{username}:{password}@{hostname}:{port}/{database}')
engine.execute("DELETE FROM elevation")
engine.execute("DELETE FROM biostrat")
elevation_finale.to_sql(name='elevation', con=engine, if_exists='append', index=True)
biostrat_finale.to_sql(name='biostrat', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# ForeignKeyViolation: insert or update on table "biostrat" violates foreign key constraint "fk_biostrat_borehole_id"
# DETAIL:  Key (borehole_id)=(1) is not present in table "borehole".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-14-9aa939364b57> in <module>
#       8 engine.execute("DELETE FROM biostrat")
#       9 elevation_finale.to_sql(name='elevation', con=engine, if_exists='append', index=True)
# ---> 10 biostrat_finale.to_sql(name='biostrat', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2613             chunksize=chunksize,
#    2614             dtype=dtype,
# -> 2615             method=method,
#    2616         )
#    2617
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1018             )
#    1019         else:
# -> 1020             return meth(self, multiparams, params)
#    1021
#    1022     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1137             distilled_params,
#    1138             compiled_sql,
# -> 1139             distilled_params,
#    1140         )
#    1141         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1262                 if not evt_handled:
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#    1266             elif not parameters and context.no_parameters:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "biostrat" violates foreign key constraint "fk_biostrat_borehole_id"
# DETAIL:  Key (borehole_id)=(1) is not present in table "borehole".
#
# [SQL: INSERT INTO biostrat (biostrat_id, depth, zone, borehole_id) VALUES (%(biostrat_id)s, %(depth)s, %(zone)s, %(borehole_id)s)]
# [parameters: ({'biostrat_id': 1, 'depth': '396', 'zone': 'Diconodinium multispinum 1aii', 'borehole_id': 1}, {'biostrat_id': 2, 'depth': '396', 'zone': 'Appendicisporites distocarinatus', 'borehole_id': 1}, {'biostrat_id': 3, 'depth': '809', 'zone': 'Pseudoceratium ludbrookiae 1b', 'borehole_id': 1}, {'biostrat_id': 4, 'depth': '992', 'zone': 'Muderongia australis 2diii Subzone', 'borehole_id': 1}, {'biostrat_id': 5, 'depth': '1027', 'zone': 'Muderongia australis 2di-2diii', 'borehole_id': 1}, {'biostrat_id': 6, 'depth': '1060', 'zone': 'Egmontodinium torynum 4ai-4aii', 'borehole_id': 1}, {'biostrat_id': 7, 'depth': '1085', 'zone': 'Dissimulidinium lobispinosum 4bi', 'borehole_id': 1}, {'biostrat_id': 8, 'depth': '1091', 'zone': 'Kalyptea wisemaniae 4biii', 'borehole_id': 1}  ... displaying 10 of 23 total bound parameter sets ...  {'biostrat_id': 22, 'depth': '2346.96', 'zone': 'upper Stage 5a', 'borehole_id': 1}, {'biostrat_id': 23, 'depth': '2420.112', 'zone': 'lower Stage 5c', 'borehole_id': 1})]
# (Background on this error at: http://sqlalche.me/e/gkpj)
